# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
from collections import Counter

# %%
data_set_path = "../dataset/dataset.csv"

# %%
training_data = pd.read_csv(data_set_path)
training_data = training_data[(training_data["bot"]==True)]
# training_data
listOfKey = []
for i in training_data["description"]:
    try:
        listOfKey = listOfKey + i.split(" ")
    except:
        pass
mappedData = Counter(listOfKey)
# print(mappedData.most_common(60))

y = [count for tag, count in mappedData.most_common(60)]
x = [tag for tag, count in mappedData.most_common(60)]
plt.figure(figsize=(20,5))
plt.bar(x, y, color='crimson')
plt.yscale('log')
plt.xticks(rotation=90)
for i, (tag, count) in enumerate(mappedData.most_common(60)):
    plt.text(i, count, f' {count} ', rotation=90,
             ha='center', va='top' if i < 10 else 'bottom', color='white' if i < 10 else 'black')
plt.xlim(-0.6, len(x)-0.4)
plt.tight_layout()
plt.show()
# Out:
# <class 'collections.Counter'>
# <class 'list'>

# %%
training_data = pd.read_csv(data_set_path)
training_data = training_data[training_data["bot"]==True]
# training_data
listOfKey = []
for i in training_data["name"]:
    listOfKey = listOfKey + i.split(" ")
mappedData = Counter(listOfKey)
# print(mappedData.most_common(60))
y = [count for tag, count in mappedData.most_common(60)]
x = [tag for tag, count in mappedData.most_common(60)]
plt.figure(figsize=(20,5))
plt.bar(x, y, color='crimson')
plt.yscale('log')
plt.xticks(rotation=90)
for i, (tag, count) in enumerate(mappedData.most_common(60)):
    plt.text(i, count, f' {count} ', rotation=90,
             ha='center', va='top' if i < 10 else 'bottom', color='white' if i < 10 else 'black')
plt.xlim(-0.6, len(x)-0.4)
plt.tight_layout()
plt.show()

# %%
training_data = pd.read_csv(data_set_path)
training_data = training_data[(training_data["bot"]==True)]
# training_data
listOfKey = []
for i in training_data["status"]:
    try:
        status = json.loads(i)
#         print(i)
        listOfKey = listOfKey + status["text"].split(" ")
    except:
        pass
mappedData = Counter(listOfKey)
# print(mappedData.most_common(60))

y = [count for tag, count in mappedData.most_common(60)]
x = [tag for tag, count in mappedData.most_common(60)]
plt.figure(figsize=(20,5))
plt.bar(x, y, color='crimson')
plt.yscale('log')
plt.xticks(rotation=90)
for i, (tag, count) in enumerate(mappedData.most_common(60)):
    plt.text(i, count, f' {count} ', rotation=90,
             ha='center', va='top' if i < 10 else 'bottom', color='white' if i < 10 else 'black')
plt.xlim(-0.6, len(x)-0.4)
plt.tight_layout()
plt.show()

# %%
training_data = pd.read_csv(data_set_path)
training_data = training_data[(training_data["bot"]==True)]
# training_data
listOfKey = []
for i in training_data["description"]:
    try:
        listOfKey = listOfKey + i.split(" ")
    except:
        pass
mappedData = Counter(listOfKey)
# print(mappedData.most_common(60))
y = [count for tag, count in mappedData.most_common(60)]
x = [tag for tag, count in mappedData.most_common(60)]
plt.figure(figsize=(20,5))
plt.bar(x, y, color='crimson')
plt.yscale('log')
plt.xticks(rotation=90)
for i, (tag, count) in enumerate(mappedData.most_common(60)):
    plt.text(i, count, f' {count} ', rotation=90,
             ha='center', va='top' if i < 10 else 'bottom', color='white' if i < 10 else 'black')
plt.xlim(-0.6, len(x)-0.4)
plt.tight_layout()
plt.show()

# %%
# bioRxiv|Game|game|botALLY|thricedotted
