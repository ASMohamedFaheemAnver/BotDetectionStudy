# %%
import tweepy

# %%
consumer_key = input("Enter API key? ")
consumer_secret = input("Enter API secret? ")
access_key = input("Enter API access key? ")
access_secret = input("Enter API access secret? ")

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

# %%
auth.set_access_token(access_key, access_secret)

# %%
api = tweepy.API(auth)

# %%
bots_list = []

# %%
for bots in tweepy.Cursor(api.list_members, '01101O10', "bot-list").items():
    bots_list.append (bots._json)

# %%
len(bots_list)
# Out:
# 262

# %%
bots_list
# Out:
# [{'id': 708102355477069824,
#   'id_str': '708102355477069824',
#   'name': 'trains botting',
#   'screen_name': 'choochoobot',
#   'location': 'Deserts, Forests, Beaches, etc',
#   'description': 'A mighty locomotive sweeps through rugged landscapes. // Eine mächtige Dampflokomotive braust durch winzige Landschaften. // by @xor',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 7960,
#   'friends_count': 8,
#   'listed_count': 334,
#   'created_at': 'Fri Mar 11 01:28:52 +0000 2016',
#   'favourites_count': 87,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 14750,
#   'lang': None,
#   'status': {'created_at': 'Sun Aug 08 10:38:30 +0000 2021',
#    'id': 1424319097320329216,
#    'id_str': '1424319097320329216',
#    'text': '⠀⠀⠀☁️☁️⠀⠀⠀⠀☁️⠀⠀⠀⠀⛅ ️⠀\n🐎         🐎  🌵      \n     🐪         🐪    \n     🚂🚃🚃🚃🚃\n            🌴       \n🐪           🐢',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'source': '<a href="https://parkerhiggins.net/2016/03/new-bot-choochoobot/" rel="nofollow">choo choo bot</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 8,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'und'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/708172651693363201/GEdCBvgz_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/708172651693363201/GEdCBvgz_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  {'id': 4493492963,
#   'id_str': '4493492963',
#   'name': 'NoHomoBot',
#   'screen_name': 'Bot_Nohomo',
#   'location': 'Satire',
#   'description': '',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 79,
#   'friends_count': 2,
#   'listed_count': 4,
#   'created_at': 'Tue Dec 15 15:53:07 +0000 2015',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 51833,
#   'lang': None,
#   'status': {'created_at': 'Fri Feb 26 21:52:40 +0000 2016',
#    'id': 703336904415125505,
#    'id_str': '703336904415125505',
#    'text': 'NoHomo https://t.co/DyBfyLa9rU',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/DyBfyLa9rU',
#       'expanded_url': 'https://twitter.com/Onweerstijnbaar/status/703336202871693312',
#       'display_url': 'twitter.com/Onweerstijnbaa…',
#       'indices': [7, 30]}]},
#    'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 703336202871693312,
#    'quoted_status_id_str': '703336202871693312',
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'es'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/676799593640828928/Y_NsK0V3_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/676799593640828928/Y_NsK0V3_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4493492963/1450195328',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  {'id': 3795943403,
#   'id_str': '3795943403',
#   'name': 'Daily Moist',
#   'screen_name': 'dailymoist',
#   'location': '',
#   'description': 'Destigmatizing a misunderstood and unappreciated part of our vocabulary.',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 570,
#   'friends_count': 160,
#   'listed_count': 13,
#   'created_at': 'Sun Sep 27 19:29:18 +0000 2015',
#   'favourites_count': 5,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 369741,
#   'lang': None,
#   'status': {'created_at': 'Thu Jan 02 22:00:00 +0000 2020',
#    'id': 1212856089773060096,
#    'id_str': '1212856089773060096',
#    'text': 'DRY',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'und'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/648318325915672576/SV_Y9mpt_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/648318325915672576/SV_Y9mpt_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  {'id': 3369559252,
#   'id_str': '3369559252',
#   'name': 'Deep Dream This',
#   'screen_name': 'DeepDreamThis',
#   'location': 'London, England',
#   'description': "Tweet me a picture and I'll #deepdream it for you! Tweet '-me' and I'll dream your avatar! List of commands here: http://t.co/BRfLYAkWBA",
#   'url': 'https://t.co/BvForGsKZn',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/BvForGsKZn',
#       'expanded_url': 'https://www.patreon.com/AlanZucconi',
#       'display_url': 'patreon.com/AlanZucconi',
#       'indices': [0, 23]}]},
#    'description': {'urls': [{'url': 'http://t.co/BRfLYAkWBA',
#       'expanded_url': 'http://www.alanzucconi.com/?p=2536',
#       'display_url': 'alanzucconi.com/?p=2536',
#       'indices': [114, 136]}]}},
#   'protected': False,
#   'followers_count': 961,
#   'friends_count': 2,
#   'listed_count': 89,
#   'created_at': 'Fri Jul 10 17:20:58 +0000 2015',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 24199,
#   'lang': None,
#   'status': {'created_at': 'Mon Jun 27 19:29:29 +0000 2016',
#    'id': 747512192828772352,
#    'id_str': '747512192828772352',
#    'text': '@mycotechnologst #deepdream -vortices https://t.co/EetOFh2RIc',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'deepdream', 'indices': [17, 27]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'mycotechnologst',
#       'name': 'Mycotechnology',
#       'id': 4427530725,
#       'id_str': '4427530725',
#       'indices': [0, 16]}],
#     'urls': [],
#     'media': [{'id': 747512190186328064,
#       'id_str': '747512190186328064',
#       'indices': [38, 61],
#       'media_url': 'http://pbs.twimg.com/media/Cl-yYGFUkAAxUuZ.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Cl-yYGFUkAAxUuZ.jpg',
#       'url': 'https://t.co/EetOFh2RIc',
#       'display_url': 'pic.twitter.com/EetOFh2RIc',
#       'expanded_url': 'https://twitter.com/DeepDreamThis/status/747512192828772352/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 600, 'h': 398, 'resize': 'fit'},
#        'medium': {'w': 600, 'h': 398, 'resize': 'fit'},
#        'large': {'w': 600, 'h': 398, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 747512190186328064,
#       'id_str': '747512190186328064',
#       'indices': [38, 61],
#       'media_url': 'http://pbs.twimg.com/media/Cl-yYGFUkAAxUuZ.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Cl-yYGFUkAAxUuZ.jpg',
#       'url': 'https://t.co/EetOFh2RIc',
#       'display_url': 'pic.twitter.com/EetOFh2RIc',
#       'expanded_url': 'https://twitter.com/DeepDreamThis/status/747512192828772352/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 600, 'h': 398, 'resize': 'fit'},
#        'medium': {'w': 600, 'h': 398, 'resize': 'fit'},
#        'large': {'w': 600, 'h': 398, 'resize': 'fit'}}}]},
#    'source': '<a href="http://www.alanzucconi.com" rel="nofollow">DeepDreamThis</a>',
#    'in_reply_to_status_id': 747511380396281856,
#    'in_reply_to_status_id_str': '747511380396281856',
#    'in_reply_to_user_id': 4427530725,
#    'in_reply_to_user_id_str': '4427530725',
#    'in_reply_to_screen_name': 'mycotechnologst',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 6,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/620560629221490688/4EDB17j8_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/620560629221490688/4EDB17j8_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3369559252/1437498363',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  {'id': 3352723458,
#   'id_str': '3352723458',
#   'name': 'Fuzzy Trends',
#   'screen_name': 'FuzzyTrends',
#   'location': 'NYC',
#   'description': 'This bot retweets recent tweets with misspelled trending hashtags. \nBuilt by @PSweetpotato',
#   'url': 'http://t.co/BoBYMnTpnx',
#   'entities': {'url': {'urls': [{'url': 'http://t.co/BoBYMnTpnx',
#       'expanded_url': 'http://psweetpotato.github.io',
#       'display_url': 'psweetpotato.github.io',
#       'indices': [0, 22]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 18,
#   'friends_count': 7,
#   'listed_count': 8,
#   'created_at': 'Wed Aug 26 22:07:22 +0000 2015',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 84,
#   'lang': None,
#   'status': {'created_at': 'Mon Oct 19 19:34:35 +0000 2015',
#    'id': 656191734033063937,
#    'id_str': '656191734033063937',
#    'text': 'RT @tasnimekhedher: @BethanyMota hope next #moravatormonday will be my luck day ilysm',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'moravatormonday', 'indices': [43, 59]}],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'BethanyMota',
#       'name': 'Bethany Mota ∞',
#       'id': 46832898,
#       'id_str': '46832898',
#       'indices': [20, 32]}],
#     'urls': []},
#    'source': '<a href="http://psweetpotato.github.io" rel="nofollow">Fuzzy Trends</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon Oct 12 20:07:08 +0000 2015',
#     'id': 653663210009165824,
#     'id_str': '653663210009165824',
#     'text': '@BethanyMota hope next #moravatormonday will be my luck day ilysm',
#     'truncated': False,
#     'entities': {'hashtags': [{'text': 'moravatormonday',
#        'indices': [23, 39]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'BethanyMota',
#        'name': 'Bethany Mota ∞',
#        'id': 46832898,
#        'id_str': '46832898',
#        'indices': [0, 12]}],
#      'urls': []},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': 46832898,
#     'in_reply_to_user_id_str': '46832898',
#     'in_reply_to_screen_name': 'BethanyMota',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 1,
#     'favorite_count': 0,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/636998421350449154/kdMOnKbx_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/636998421350449154/kdMOnKbx_normal.png',
#   'profile_link_color': 'FEA650',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  {'id': 3268879490,
#   'id_str': '3268879490',
#   'name': 'Deepdream bot',
#   'screen_name': 'DeepdreamBot',
#   'location': 'Yoyogi, Tokyo',
#   'description': '',
#   'url': 'http://t.co/8H25jlNM5z',
#   'entities': {'url': {'urls': [{'url': 'http://t.co/8H25jlNM5z',
#       'expanded_url': 'http://psychic-vr-lab.com/deepdream/',
#       'display_url': 'psychic-vr-lab.com/deepdream/',
#       'indices': [0, 22]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 1814,
#   'friends_count': 6,
#   'listed_count': 85,
#   'created_at': 'Sun Jul 05 08:13:42 +0000 2015',
#   'favourites_count': 69,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 26044,
#   'lang': None,
#   'status': {'created_at': 'Mon Jul 29 12:19:12 +0000 2019',
#    'id': 1155815031302262785,
#    'id_str': '1155815031302262785',
#    'text': '#deepdream https://t.co/a22Ps34F7I https://t.co/4xuklDmkIG',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'deepdream', 'indices': [0, 10]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/a22Ps34F7I',
#       'expanded_url': 'http://psychic-vr-lab.com/deepdream/pics/1453613.html',
#       'display_url': 'psychic-vr-lab.com/deepdream/pics…',
#       'indices': [11, 34]}],
#     'media': [{'id': 1155815028026556416,
#       'id_str': '1155815028026556416',
#       'indices': [35, 58],
#       'media_url': 'http://pbs.twimg.com/media/EApHpOuUwAAft6R.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EApHpOuUwAAft6R.jpg',
#       'url': 'https://t.co/4xuklDmkIG',
#       'display_url': 'pic.twitter.com/4xuklDmkIG',
#       'expanded_url': 'https://twitter.com/DeepdreamBot/status/1155815031302262785/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 640, 'h': 640, 'resize': 'fit'},
#        'large': {'w': 640, 'h': 640, 'resize': 'fit'},
#        'small': {'w': 640, 'h': 640, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1155815028026556416,
#       'id_str': '1155815028026556416',
#       'indices': [35, 58],
#       'media_url': 'http://pbs.twimg.com/media/EApHpOuUwAAft6R.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EApHpOuUwAAft6R.jpg',
#       'url': 'https://t.co/4xuklDmkIG',
#       'display_url': 'pic.twitter.com/4xuklDmkIG',
#       'expanded_url': 'https://twitter.com/DeepdreamBot/status/1155815031302262785/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 640, 'h': 640, 'resize': 'fit'},
#        'large': {'w': 640, 'h': 640, 'resize': 'fit'},
#        'small': {'w': 640, 'h': 640, 'resize': 'fit'}}}]},
#    'source': '<a href="http://psychic-vr-lab.com/deepdream/" rel="nofollow">deepdream</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 5,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': True,
#    'lang': 'und'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/617608054444396544/tWMVXPfu_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/617608054444396544/tWMVXPfu_normal.png',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3268879490/1436343548',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  {'id': 3183086418,
#   'id_str': '3183086418',
#   'name': 'Turns Out For Bot',
#   'screen_name': 'TurnsOutBot',
#   'location': '',
#   'description': '',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 110,
#   'friends_count': 0,
#   'listed_count': 6,
#   'created_at': 'Sat May 02 16:34:27 +0000 2015',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 144271,
#   'lang': None,
#   'status': {'created_at': 'Thu Mar 03 14:06:19 +0000 2016',
#    'id': 705393870650142720,
#    'id_str': '705393870650142720',
#    'text': 'RT: https://t.co/Smh0gyptns',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/Smh0gyptns',
#       'expanded_url': 'https://twitter.com/blagmatic/status/705393741121626112',
#       'display_url': 'twitter.com/blagmatic/stat…',
#       'indices': [4, 27]}]},
#    'source': '<a href="https://ifttt.com" rel="nofollow">IFTTT</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 705393741121626112,
#    'quoted_status_id_str': '705393741121626112',
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'und'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#   'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': True,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  {'id': 3041436185,
#   'id_str': '3041436185',
#   'name': 'dnstats_agora',
#   'screen_name': 'dnstats_agora',
#   'location': '',
#   'description': '',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 836,
#   'friends_count': 1,
#   'listed_count': 5,
#   'created_at': 'Mon Feb 16 21:08:38 +0000 2015',
#   'favourites_count': 1,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 3549,
#   'lang': None,
#   'status': {'created_at': 'Sat Sep 12 03:55:01 +0000 2015',
#    'id': 642546932590755840,
#    'id_str': '642546932590755840',
#    'text': 'Agora Registrations are Open Check http://t.co/rPMpPBrEzq',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'http://t.co/rPMpPBrEzq',
#       'expanded_url': 'http://isagoraup.com',
#       'display_url': 'isagoraup.com',
#       'indices': [35, 57]}]},
#    'source': '<a href="https://dnstats.net/market/agora" rel="nofollow">Agora stats</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/567442604208312320/zvnC2_zx_normal.jpeg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/567442604208312320/zvnC2_zx_normal.jpeg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  {'id': 2980456333,
#   'id_str': '2980456333',
#   'name': 'More Pushups Than U',
#   'screen_name': 'ididmorepushups',
#   'location': '',
#   'description': '',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 5349,
#   'friends_count': 2,
#   'listed_count': 10,
#   'created_at': 'Tue Jan 13 19:42:21 +0000 2015',
#   'favourites_count': 43,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 131,
#   'lang': None,
#   'status': {'created_at': 'Fri May 07 21:33:36 +0000 2021',
#    'id': 1390781888869146624,
#    'id_str': '1390781888869146624',
#    'text': 'trying to “meet” the presidents fitness challenge as quickly as possible in third grade ass form. awful pushhups. q… https://t.co/5ORK4eSOiC',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/5ORK4eSOiC',
#       'expanded_url': 'https://twitter.com/i/web/status/1390781888869146624',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1390737329090973696,
#    'in_reply_to_status_id_str': '1390737329090973696',
#    'in_reply_to_user_id': 2980456333,
#    'in_reply_to_user_id_str': '2980456333',
#    'in_reply_to_screen_name': 'ididmorepushups',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 19,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/619169349748817920/D9H76HTz_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/619169349748817920/D9H76HTz_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  {'id': 2901778089,
#   'id_str': '2901778089',
#   'name': 'BMPBug',
#   'screen_name': 'BMPBug',
#   'location': '',
#   'description': "My BMP converter has a bizare bug, send me pictures and you'll see. I am a strong believer in the full potential of other bots. See terms in link.",
#   'url': 'https://t.co/S7QmaGvbrE',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/S7QmaGvbrE',
#       'expanded_url': 'https://github.com/vexorian/bmpbug-source',
#       'display_url': 'github.com/vexorian/bmpbu…',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 387,
#   'friends_count': 75,
#   'listed_count': 79,
#   'created_at': 'Tue Dec 02 03:37:16 +0000 2014',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 115356,
#   'lang': None,
#   'status': {'created_at': 'Wed Jul 06 22:17:11 +0000 2016',
#    'id': 750815886244716544,
#    'id_str': '750815886244716544',
#    'text': "(That's why I like imgshredder https://t.co/wWDrpKhkju )",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/wWDrpKhkju',
#       'expanded_url': 'https://twitter.com/imgshredder/status/750753333648977921',
#       'display_url': 'twitter.com/imgshredder/st…',
#       'indices': [31, 54]}]},
#    'source': '<a href="https://twitter.com" rel="nofollow">BadBMP</a>',
#    'in_reply_to_status_id': 750815792623681536,
#    'in_reply_to_status_id_str': '750815792623681536',
#    'in_reply_to_user_id': 2901778089,
#    'in_reply_to_user_id_str': '2901778089',
#    'in_reply_to_screen_name': 'BMPBug',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 750753333648977921,
#    'quoted_status_id_str': '750753333648977921',
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/539631522622345217/vkSxpX3A_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/539631522622345217/vkSxpX3A_normal.png',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  {'id': 2900906989,
#   'id_str': '2900906989',
#   'name': 'PleaseRapAbout',
#   'screen_name': 'PleaseRapAbout',
#   'location': '',
#   'description': 'If you follow me and tweet a word to me, I will reply with a freestyle – RT if you like it! I am a bot by @studiomoniker',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 2676,
#   'friends_count': 7,
#   'listed_count': 0,
#   'created_at': 'Sat Nov 15 21:26:31 +0000 2014',
#   'favourites_count': 121,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 72621,
#   'lang': None,
#   'status': {'created_at': 'Tue Aug 16 13:47:39 +0000 2016',
#    'id': 765545562351538176,
#    'id_str': '765545562351538176',
#    'text': "@sammysnapshots\ndon't hug me i'm scared?\nThe moments that we shared\nHave you ever been held\nALL THE HOMIES STARED",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'source': '<a href="http://pleaserapabout.com" rel="nofollow">RapBot Revised</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/535864979774140416/ip874Y0N_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/535864979774140416/ip874Y0N_normal.png',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2900906989/1417182071',
#   'profile_link_color': '000000',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  {'id': 2896395513,
#   'id_str': '2896395513',
#   'name': 'Word Tweet Cloud Bot',
#   'screen_name': 'wordnuvola',
#   'location': 'Liguria, Italy',
#   'description': 'Wanna see your most used words on twitter in a single image?read the banner',
#   'url': 'https://t.co/ud2YOsje3f',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/ud2YOsje3f',
#       'expanded_url': 'http://www.walloop.com',
#       'display_url': 'walloop.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 87218,
#   'friends_count': 3682,
#   'listed_count': 93,
#   'created_at': 'Fri Nov 28 20:52:04 +0000 2014',
#   'favourites_count': 2219,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 670321,
#   'lang': None,
#   'status': {'created_at': 'Sun Aug 08 12:38:11 +0000 2021',
#    'id': 1424349219779919876,
#    'id_str': '1424349219779919876',
#    'text': '@yovrsoogoldcn Deploy your next app in seconds. Get $100 in cloud credits from @DigitalOcean using my link:… https://t.co/BXNKM7rRlu',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'yovrsoogoldcn',
#       'name': 'maris⁷; junie day',
#       'id': 1320751949009080321,
#       'id_str': '1320751949009080321',
#       'indices': [0, 14]},
#      {'screen_name': 'digitalocean',
#       'name': 'DigitalOcean',
#       'id': 457033547,
#       'id_str': '457033547',
#       'indices': [79, 92]}],
#     'urls': [{'url': 'https://t.co/BXNKM7rRlu',
#       'expanded_url': 'https://twitter.com/i/web/status/1424349219779919876',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [109, 132]}]},
#    'source': '<a href="http://www.iwillmakethiswebsite321324.io" rel="nofollow">wordnuvola</a>',
#    'in_reply_to_status_id': 1424056263537799168,
#    'in_reply_to_status_id_str': '1424056263537799168',
#    'in_reply_to_user_id': 1320751949009080321,
#    'in_reply_to_user_id_str': '1320751949009080321',
#    'in_reply_to_screen_name': 'yovrsoogoldcn',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'ja'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1133446476082929664/bRLBrKrF_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1133446476082929664/bRLBrKrF_normal.png',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2896395513/1547912798',
#   'profile_link_color': '1B95E0',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  {'id': 2887281063,
#   'id_str': '2887281063',
#   'name': 'Roberts & Roberts',
#   'screen_name': 'fullmetaliberty',
#   'location': 'Pensacola, FL',
#   'description': 'Serving clients for over 40 years. We buy and sell physical precious metals and have been accepting Bitcoin since 2013. Not your average brokerage firm.',
#   'url': 'https://t.co/JiT3e1B7Eq',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/JiT3e1B7Eq',
#       'expanded_url': 'http://rrbi.co',
#       'display_url': 'rrbi.co',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 689,
#   'friends_count': 776,
#   'listed_count': 47,
#   'created_at': 'Fri Nov 21 20:38:20 +0000 2014',
#   'favourites_count': 1123,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 5184,
#   'lang': None,
#   'status': {'created_at': 'Fri Aug 06 19:31:03 +0000 2021',
#    'id': 1423728345548791817,
#    'id_str': '1423728345548791817',
#    'text': 'Gold $1,764.10 | Silver $24.38 | Platinum $976.00\nBitcoin $42,865 | Bitcoin Cash $554 \nCall us at 800-874-9760 or s… https://t.co/zWKZbiofr7',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/zWKZbiofr7',
#       'expanded_url': 'https://twitter.com/i/web/status/1423728345548791817',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'source': '<a href="http://rrbi.co" rel="nofollow">PeaceBot-MetalsFeed</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/570244281395200000/MWnizs5P_normal.jpeg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/570244281395200000/MWnizs5P_normal.jpeg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2887281063/1424791793',
#   'profile_link_color': '000000',
#   'profile_sidebar_border_color': '181A1E',
#   'profile_sidebar_fill_color': '252429',
#   'profile_text_color': '666666',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  {'id': 2885019155,
#   'id_str': '2885019155',
#   'name': 'Danny Devito Bot',
#   'screen_name': 'DannyDevitoBot',
#   'location': '',
#   'description': 'I find tweets about Danny Devito.',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 395,
#   'friends_count': 5,
#   'listed_count': 14,
#   'created_at': 'Thu Nov 20 00:05:34 +0000 2014',
#   'favourites_count': 7,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 71557,
#   'lang': None,
#   'status': {'created_at': 'Sat Mar 25 04:15:20 +0000 2017',
#    'id': 845489249797505024,
#    'id_str': '845489249797505024',
#    'text': 'featuring danny devito https://t.co/ZHP1fxbcON',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/ZHP1fxbcON',
#       'expanded_url': 'https://twitter.com/shitsketchs/status/845487727483138049/photo/1',
#       'display_url': 'pic.twitter.com/ZHP1fxbcON',
#       'indices': [23, 46]}]},
#    'source': '<a href="http://www.powerapps.com" rel="nofollow">Microsoft Power Platform</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 6,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/535222646963572736/KZItD1f-_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/535222646963572736/KZItD1f-_normal.png',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  {'id': 2884236207,
#   'id_str': '2884236207',
#   'name': 'DataLeakBot',
#   'screen_name': 'DataLeakBot',
#   'location': '',
#   'description': 'I am a bot keeping an eye on data leaks. \n\nCurrently I am down for maintenance',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 539,
#   'friends_count': 441,
#   'listed_count': 33,
#   'created_at': 'Wed Nov 19 16:29:52 +0000 2014',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 32121,
#   'lang': None,
#   'status': {'created_at': 'Mon Aug 01 11:07:48 +0000 2016',
#    'id': 760069516525264896,
#    'id_str': '760069516525264896',
#    'text': "I'm alive... my master has fixed my broken parts.",
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/535183130986958848/A_l53IEs_normal.jpeg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/535183130986958848/A_l53IEs_normal.jpeg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  {'id': 2883449266,
#   'id_str': '2883449266',
#   'name': 'IMG2ASCII',
#   'screen_name': 'IMG2ASCII',
#   'location': 'Some BBS somewhere',
#   'description': 'Tweet me an image and I will make it look like ASCII art. instructions at http://t.co/xO9X63ledz a bot from @muffinista #botALLY',
#   'url': 'http://t.co/wpsRGPhEIg',
#   'entities': {'url': {'urls': [{'url': 'http://t.co/wpsRGPhEIg',
#       'expanded_url': 'http://muffinlabs.com/IMG2ASCII',
#       'display_url': 'muffinlabs.com/IMG2ASCII',
#       'indices': [0, 22]}]},
#    'description': {'urls': [{'url': 'http://t.co/xO9X63ledz',
#       'expanded_url': 'http://muffinlabs.com/IMG2ASCII/',
#       'display_url': 'muffinlabs.com/IMG2ASCII/',
#       'indices': [74, 96]}]}},
#   'protected': False,
#   'followers_count': 1280,
#   'friends_count': 1376,
#   'listed_count': 114,
#   'created_at': 'Wed Nov 19 01:00:08 +0000 2014',
#   'favourites_count': 0,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 29584,
#   'lang': None,
#   'status': {'created_at': 'Thu May 10 16:02:31 +0000 2018',
#    'id': 994608630262530049,
#    'id_str': '994608630262530049',
#    'text': '@CommonsBot https://t.co/B1WyyZDpB4',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'CommonsBot',
#       'name': 'CommonsBot',
#       'id': 2892078532,
#       'id_str': '2892078532',
#       'indices': [0, 11]}],
#     'urls': [],
#     'media': [{'id': 994608628853362688,
#       'id_str': '994608628853362688',
#       'indices': [12, 35],
#       'media_url': 'http://pbs.twimg.com/media/Dc2PRz1X0AAelMu.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Dc2PRz1X0AAelMu.jpg',
#       'url': 'https://t.co/B1WyyZDpB4',
#       'display_url': 'pic.twitter.com/B1WyyZDpB4',
#       'expanded_url': 'https://twitter.com/IMG2ASCII/status/994608630262530049/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 413, 'h': 800, 'resize': 'fit'},
#        'small': {'w': 351, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 413, 'h': 800, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 994608628853362688,
#       'id_str': '994608628853362688',
#       'indices': [12, 35],
#       'media_url': 'http://pbs.twimg.com/media/Dc2PRz1X0AAelMu.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/Dc2PRz1X0AAelMu.jpg',
#       'url': 'https://t.co/B1WyyZDpB4',
#       'display_url': 'pic.twitter.com/B1WyyZDpB4',
#       'expanded_url': 'https://twitter.com/IMG2ASCII/status/994608630262530049/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 413, 'h': 800, 'resize': 'fit'},
#        'small': {'w': 351, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 413, 'h': 800, 'resize': 'fit'}}}]},
#    'source': '<a href="http://muffinlabs.com" rel="nofollow">botly</a>',
#    'in_reply_to_status_id': 994608621303619584,
#    'in_reply_to_status_id_str': '994608621303619584',
#    'in_reply_to_user_id': 2892078532,
#    'in_reply_to_user_id_str': '2892078532',
#    'in_reply_to_screen_name': 'CommonsBot',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
# ...
#   'url': 'https://t.co/eejAg9NIH6',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/eejAg9NIH6',
#       'expanded_url': 'http://www.urbandictionary.com/',
#       'display_url': 'urbandictionary.com',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 325473,
#   'friends_count': 3,
#   'listed_count': 2594,
#   'created_at': 'Mon Jul 21 17:32:55 +0000 2008',
#   'favourites_count': 7,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': True,
#   'statuses_count': 5740202,
#   'lang': None,
#   'status': {'created_at': 'Sun Aug 08 12:30:48 +0000 2021',
#    'id': 1424347360335851533,
#    'id_str': '1424347360335851533',
#    'text': '@i94lvz july 19: The day woah vicky found out she was black https://t.co/Tji6mrzdBT https://t.co/2qWO5Bvxbr',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'i94lvz',
#       'name': '## niko !',
#       'id': 1162820608012369920,
#       'id_str': '1162820608012369920',
#       'indices': [0, 7]}],
#     'urls': [{'url': 'https://t.co/Tji6mrzdBT',
#       'expanded_url': 'http://july-19.urbanup.com/13964383',
#       'display_url': 'july-19.urbanup.com/13964383',
#       'indices': [60, 83]}],
#     'media': [{'id': 1424347359291478022,
#       'id_str': '1424347359291478022',
#       'indices': [84, 107],
#       'media_url': 'http://pbs.twimg.com/media/E8RMYHNVkAYDPvd.png',
#       'media_url_https': 'https://pbs.twimg.com/media/E8RMYHNVkAYDPvd.png',
#       'url': 'https://t.co/2qWO5Bvxbr',
#       'display_url': 'pic.twitter.com/2qWO5Bvxbr',
#       'expanded_url': 'https://twitter.com/urbandictionary/status/1424347360335851533/photo/1',
#       'type': 'photo',
#       'sizes': {'large': {'w': 506, 'h': 478, 'resize': 'fit'},
#        'medium': {'w': 506, 'h': 478, 'resize': 'fit'},
#        'small': {'w': 506, 'h': 478, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]},
#    'extended_entities': {'media': [{'id': 1424347359291478022,
#       'id_str': '1424347359291478022',
#       'indices': [84, 107],
#       'media_url': 'http://pbs.twimg.com/media/E8RMYHNVkAYDPvd.png',
#       'media_url_https': 'https://pbs.twimg.com/media/E8RMYHNVkAYDPvd.png',
#       'url': 'https://t.co/2qWO5Bvxbr',
#       'display_url': 'pic.twitter.com/2qWO5Bvxbr',
#       'expanded_url': 'https://twitter.com/urbandictionary/status/1424347360335851533/photo/1',
#       'type': 'photo',
#       'sizes': {'large': {'w': 506, 'h': 478, 'resize': 'fit'},
#        'medium': {'w': 506, 'h': 478, 'resize': 'fit'},
#        'small': {'w': 506, 'h': 478, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}}}]},
#    'source': '<a href="https://www.urbandictionary.com" rel="nofollow">urbanbot</a>',
#    'in_reply_to_status_id': 1424347334444339207,
#    'in_reply_to_status_id_str': '1424347334444339207',
#    'in_reply_to_user_id': 1162820608012369920,
#    'in_reply_to_user_id_str': '1162820608012369920',
#    'in_reply_to_screen_name': 'i94lvz',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '4B4C4D',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme5/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme5/bg.gif',
#   'profile_background_tile': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1149416858426081280/uvwDuyqS_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1149416858426081280/uvwDuyqS_normal.png',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15518000/1562950712',
#   'profile_link_color': '2C51DC',
#   'profile_sidebar_border_color': 'CFCFCF',
#   'profile_sidebar_fill_color': 'F0F0F0',
#   'profile_text_color': '4B4C4D',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'regular',
#   'withheld_in_countries': []},
#  {'id': 14985586,
#   'id_str': '14985586',
#   'name': 'Garry12gg',
#   'screen_name': 'garry12gg',
#   'location': 'Texas',
#   'description': 'I like to learn new things and play video games.',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 846,
#   'friends_count': 2293,
#   'listed_count': 13,
#   'created_at': 'Mon Jun 02 21:45:35 +0000 2008',
#   'favourites_count': 3766,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 60384,
#   'lang': None,
#   'status': {'created_at': 'Sun Aug 08 00:39:13 +0000 2021',
#    'id': 1424168284589539329,
#    'id_str': '1424168284589539329',
#    'text': 'RT @WholesomeMeme: https://t.co/1121egNPTl',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'WholesomeMeme',
#       'name': 'WholesomeMemes',
#       'id': 762799939395158016,
#       'id_str': '762799939395158016',
#       'indices': [3, 17]}],
#     'urls': [],
#     'media': [{'id': 1424000238042468352,
#       'id_str': '1424000238042468352',
#       'indices': [19, 42],
#       'media_url': 'http://pbs.twimg.com/media/E8MQq_yX0AAPDQv.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/E8MQq_yX0AAPDQv.jpg',
#       'url': 'https://t.co/1121egNPTl',
#       'display_url': 'pic.twitter.com/1121egNPTl',
#       'expanded_url': 'https://twitter.com/WholesomeMeme/status/1424052720164425728/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1080, 'h': 1075, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 677, 'resize': 'fit'},
#        'large': {'w': 1080, 'h': 1075, 'resize': 'fit'}},
#       'source_status_id': 1424052720164425728,
#       'source_status_id_str': '1424052720164425728',
#       'source_user_id': 762799939395158016,
#       'source_user_id_str': '762799939395158016'}]},
#    'extended_entities': {'media': [{'id': 1424000238042468352,
#       'id_str': '1424000238042468352',
#       'indices': [19, 42],
#       'media_url': 'http://pbs.twimg.com/media/E8MQq_yX0AAPDQv.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/E8MQq_yX0AAPDQv.jpg',
#       'url': 'https://t.co/1121egNPTl',
#       'display_url': 'pic.twitter.com/1121egNPTl',
#       'expanded_url': 'https://twitter.com/WholesomeMeme/status/1424052720164425728/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1080, 'h': 1075, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 677, 'resize': 'fit'},
#        'large': {'w': 1080, 'h': 1075, 'resize': 'fit'}},
#       'source_status_id': 1424052720164425728,
#       'source_status_id_str': '1424052720164425728',
#       'source_user_id': 762799939395158016,
#       'source_user_id_str': '762799939395158016'}]},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Aug 07 17:00:00 +0000 2021',
#     'id': 1424052720164425728,
#     'id_str': '1424052720164425728',
#     'text': 'https://t.co/1121egNPTl',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [],
#      'urls': [],
#      'media': [{'id': 1424000238042468352,
#        'id_str': '1424000238042468352',
#        'indices': [0, 23],
#        'media_url': 'http://pbs.twimg.com/media/E8MQq_yX0AAPDQv.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/E8MQq_yX0AAPDQv.jpg',
#        'url': 'https://t.co/1121egNPTl',
#        'display_url': 'pic.twitter.com/1121egNPTl',
#        'expanded_url': 'https://twitter.com/WholesomeMeme/status/1424052720164425728/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1080, 'h': 1075, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 677, 'resize': 'fit'},
#         'large': {'w': 1080, 'h': 1075, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1424000238042468352,
#        'id_str': '1424000238042468352',
#        'indices': [0, 23],
#        'media_url': 'http://pbs.twimg.com/media/E8MQq_yX0AAPDQv.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/E8MQq_yX0AAPDQv.jpg',
#        'url': 'https://t.co/1121egNPTl',
#        'display_url': 'pic.twitter.com/1121egNPTl',
#        'expanded_url': 'https://twitter.com/WholesomeMeme/status/1424052720164425728/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'medium': {'w': 1080, 'h': 1075, 'resize': 'fit'},
#         'small': {'w': 680, 'h': 677, 'resize': 'fit'},
#         'large': {'w': 1080, 'h': 1075, 'resize': 'fit'}}}]},
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 12796,
#     'favorite_count': 105987,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'und'},
#    'is_quote_status': False,
#    'retweet_count': 12796,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'und'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/978876762607284230/qTquOPIY_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/978876762607284230/qTquOPIY_normal.jpg',
#   'profile_link_color': '1B95E0',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'regular',
#   'withheld_in_countries': []},
#  {'id': 7520962,
#   'id_str': '7520962',
#   'name': 'David Smith',
#   'screen_name': 'mylife',
#   'location': 'Texas',
#   'description': 'Responding to your rhetorical tweets since 2007.',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 244,
#   'friends_count': 0,
#   'listed_count': 7,
#   'created_at': 'Tue Jul 17 01:18:48 +0000 2007',
#   'favourites_count': 10,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'verified': False,
#   'statuses_count': 5953,
#   'lang': None,
#   'status': {'created_at': 'Sun Dec 20 23:13:24 +0000 2020',
#    'id': 1340797478451482630,
#    'id_str': '1340797478451482630',
#    'text': '@Carwhorns trying to sign up on website no luck',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'Carwhorns',
#       'name': '💸💸',
#       'id': 2372215790,
#       'id_str': '2372215790',
#       'indices': [0, 10]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': 2372215790,
#    'in_reply_to_user_id_str': '2372215790',
#    'in_reply_to_screen_name': 'Carwhorns',
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '1A1B1F',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/2967659934/145c3f85a88993a85cae553240857d80_normal.jpeg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2967659934/145c3f85a88993a85cae553240857d80_normal.jpeg',
#   'profile_link_color': '2FC2EF',
#   'profile_sidebar_border_color': '181A1E',
#   'profile_sidebar_fill_color': '252429',
#   'profile_text_color': '666666',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'regular',
#   'withheld_in_countries': []},
#  {'id': 5747362,
#   'id_str': '5747362',
#   'name': 'Jerkomatic',
#   'screen_name': 'jerkomatic',
#   'location': '',
#   'description': '',
#   'url': 'http://t.co/vdeBP9B9WB',
#   'entities': {'url': {'urls': [{'url': 'http://t.co/vdeBP9B9WB',
#       'expanded_url': 'http://jerkcity.com/',
#       'display_url': 'jerkcity.com',
#       'indices': [0, 22]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 716,
#   'friends_count': 14,
#   'listed_count': 33,
#   'created_at': 'Thu May 03 18:10:03 +0000 2007',
#   'favourites_count': 1,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 4408,
#   'lang': None,
#   'status': {'created_at': 'Wed Jun 16 15:46:03 +0000 2021',
#    'id': 1405189937926852609,
#    'id_str': '1405189937926852609',
#    'text': 'HOW CAN A VIRUS THAT KILLS EVERYTHING STAY ALIVE FOR NINETY BORING MINUTES',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'source': '<a href="http://code.google.com/p/python-twitter/" rel="nofollow">Twatsie@Jerkomatic</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'CCCCCC',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/53360330/probe_droid_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/53360330/probe_droid_normal.jpg',
#   'profile_link_color': '0000FF',
#   'profile_sidebar_border_color': 'DDDDDD',
#   'profile_sidebar_fill_color': 'EEEEEE',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []}]
